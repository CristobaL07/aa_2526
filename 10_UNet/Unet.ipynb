# %% [markdown]
# # Segmentació d’Imatges amb U-Net
#
# En aquesta pràctica treballarem amb U-Net, una de les arquitectures més utilitzades en tasques de segmentació d'imatges. L'objectiu principal és consolidar els coneixements teòrics adquirits, implementant i experimentant amb aquesta xarxa utilitzant un conjunt de dades artificial i simple.
#
# La segmentació d'imatges és una tasca fonamental en visió per computador, ja que permet classificar cada píxel d'una imatge en una o més categories. En aquesta pràctica, el nostre objectiu serà entrenar una xarxa U-Net perquè pugui identificar regions específiques dins d’imatges generades artificialment. Aquest enfocament simplificat permetrà concentrar-nos en els aspectes clau de la implementació i el funcionament del model, sense les complicacions que podrien sorgir amb conjunts de dades més complexos.
#
# El conjunt de dades que utilitzarem estarà format per imatges sintètiques que contenen formes geomètriques bàsiques (com cercles, quadrats o creus), amb les seves corresponents màscares que indiquen les àrees que cal segmentar. Això ens permetrà obtenir resultats visuals ràpidament i entendre millor com la xarxa aprèn a identificar patrons específics.
#
# L'arquitectura que emprarem es pot utilitzar, per problemes més complexes, però amb les limitacions temporals que tenim no es recomenable.

# %%
from collections import OrderedDict
from glob import glob

import cv2
import matplotlib.pyplot as plt
import numpy as np
import pylab as pl
import torch
import torch.nn as nn
import torch.optim as optim
from IPython import display
from torch.utils.data import Dataset
from torchvision import transforms
from tqdm.auto import tqdm

# %% [markdown]
# ## Dataset
#
# Emprarem un dataset sintètic. Aquest originalment s'emprava per dur a terme tasques de Intel·ligència Artificial Explicable (XAI). Nosaltres ho emprarem per dur a terme una tasca de segmentació. Podeu trobar el dataset complet al següent [enllaç](https://github.com/miquelmn/aixi-dataset/releases/tag/1.5.0).
#
# ![Imatges dataset](https://ars.els-cdn.com/content/image/1-s2.0-S0004370224001152-gr001.jpg)
#
# L'objectiu amb aquest dataset es segmentar del fons les formes geomètriques, emprant una U-Net. Nosaltres i a causa de les limitacions temporals que tenim i de recursos emprarem una versió [reduida](https://github.com/miquelmn/aa_2526/releases/tag/pr9).

# %%
# !unzip mini_txuxi.zip -d /content/
# Out:
# Archive:  mini_txuxi.zip
# replace /content/mini/train/image/00000.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: /content/mini/train/image/00000.png
#   inflating: /content/mini/train/image/00001.png
#   inflating: /content/mini/train/image/00002.png
#   inflating: /content/mini/train/image/00003.png
#   inflating: /content/mini/train/image/00004.png
#   inflating: /content/mini/train/image/00005.png
#   inflating: /content/mini/train/image/00006.png
#   inflating: /content/mini/train/image/00007.png
#   inflating: /content/mini/train/image/00008.png
#   inflating: /content/mini/train/image/00009.png
#   inflating: /content/mini/train/image/00010.png
#   inflating: /content/mini/train/image/00011.png
#   inflating: /content/mini/train/image/00012.png
#   inflating: /content/mini/train/image/00013.png
#   inflating: /content/mini/train/image/00014.png
#   inflating: /content/mini/train/image/00015.png
#   inflating: /content/mini/train/image/00016.png
#   inflating: /content/mini/train/image/00017.png
#   inflating: /content/mini/train/image/00018.png
#   inflating: /content/mini/train/image/00019.png
#   inflating: /content/mini/train/image/00020.png
#   inflating: /content/mini/train/image/00021.png
#   inflating: /content/mini/train/image/00022.png
#   inflating: /content/mini/train/image/00023.png
#   inflating: /content/mini/train/image/00024.png
#   inflating: /content/mini/train/image/00025.png
#   inflating: /content/mini/train/image/00026.png
#   inflating: /content/mini/train/image/00027.png
#   inflating: /content/mini/train/image/00028.png
#   inflating: /content/mini/train/image/00029.png
#   inflating: /content/mini/train/image/00030.png
#   inflating: /content/mini/train/image/00031.png
#   inflating: /content/mini/train/image/00032.png
#   inflating: /content/mini/train/image/00033.png
#   inflating: /content/mini/train/image/00034.png
#   inflating: /content/mini/train/image/00035.png
#   inflating: /content/mini/train/image/00036.png
#   inflating: /content/mini/train/image/00037.png
#   inflating: /content/mini/train/image/00038.png
#   inflating: /content/mini/train/image/00039.png
#   inflating: /content/mini/train/image/00040.png
#   inflating: /content/mini/train/image/00041.png
#   inflating: /content/mini/train/image/00042.png
#   inflating: /content/mini/train/image/00043.png
#   inflating: /content/mini/train/image/00044.png
#   inflating: /content/mini/train/image/00045.png
#   inflating: /content/mini/train/image/00046.png
#   inflating: /content/mini/train/image/00047.png
#   inflating: /content/mini/train/image/00048.png
#   inflating: /content/mini/train/image/00049.png
#   inflating: /content/mini/train/image/00050.png
#   inflating: /content/mini/train/image/00051.png
#   inflating: /content/mini/train/image/00052.png
#   inflating: /content/mini/train/image/00053.png
#   inflating: /content/mini/train/image/00054.png
#   inflating: /content/mini/train/image/00055.png
#   inflating: /content/mini/train/image/00056.png
#   inflating: /content/mini/train/image/00057.png
#   inflating: /content/mini/train/image/00058.png
#   inflating: /content/mini/train/image/00059.png
#   inflating: /content/mini/train/image/00060.png
#   inflating: /content/mini/train/image/00061.png
#   inflating: /content/mini/train/image/00062.png
#   inflating: /content/mini/train/image/00063.png
#   inflating: /content/mini/train/image/00064.png
#   inflating: /content/mini/train/image/00065.png
#   inflating: /content/mini/train/image/00066.png
#   inflating: /content/mini/train/image/00067.png
#   inflating: /content/mini/train/image/00068.png
#   inflating: /content/mini/train/image/00069.png
#   inflating: /content/mini/train/image/00070.png
#   inflating: /content/mini/train/image/00071.png
#   inflating: /content/mini/train/image/00072.png
#   inflating: /content/mini/train/image/00073.png
#   inflating: /content/mini/train/image/00074.png
#   inflating: /content/mini/train/image/00075.png
#   inflating: /content/mini/train/image/00076.png
#   inflating: /content/mini/train/image/00077.png
#   inflating: /content/mini/train/image/00078.png
#   inflating: /content/mini/train/image/00079.png
#   inflating: /content/mini/train/image/00080.png
#   inflating: /content/mini/train/image/00081.png
#   inflating: /content/mini/train/image/00082.png
#   inflating: /content/mini/train/image/00083.png
#   inflating: /content/mini/train/image/00084.png
#   inflating: /content/mini/train/image/00085.png
#   inflating: /content/mini/train/image/00086.png
#   inflating: /content/mini/train/image/00087.png
#   inflating: /content/mini/train/image/00088.png
#   inflating: /content/mini/train/image/00089.png
#   inflating: /content/mini/train/image/00090.png
#   inflating: /content/mini/train/image/00091.png
#   inflating: /content/mini/train/image/00092.png
#   inflating: /content/mini/train/image/00093.png
#   inflating: /content/mini/train/image/00094.png
#   inflating: /content/mini/train/image/00095.png
#   inflating: /content/mini/train/image/00096.png
#   inflating: /content/mini/train/image/00097.png
#   inflating: /content/mini/train/image/00098.png
#   inflating: /content/mini/train/image/00099.png
#   inflating: /content/mini/train/image/00100.png
#   inflating: /content/mini/train/image/00101.png
#   inflating: /content/mini/train/image/00102.png
#   inflating: /content/mini/train/image/00103.png
#   inflating: /content/mini/train/image/00104.png
#   inflating: /content/mini/train/image/00105.png
#   inflating: /content/mini/train/image/00106.png
#   inflating: /content/mini/train/image/00107.png
#   inflating: /content/mini/train/image/00108.png
#   inflating: /content/mini/train/image/00109.png
#   inflating: /content/mini/train/image/00110.png
#   inflating: /content/mini/train/image/00111.png
#   inflating: /content/mini/train/image/00112.png
#   inflating: /content/mini/train/image/00113.png
#   inflating: /content/mini/train/image/00114.png
#   inflating: /content/mini/train/image/00115.png
#   inflating: /content/mini/train/image/00116.png
#   inflating: /content/mini/train/image/00117.png
#   inflating: /content/mini/train/image/00118.png
#   inflating: /content/mini/train/image/00119.png
#   inflating: /content/mini/train/image/00120.png
#   inflating: /content/mini/train/image/00121.png
#   inflating: /content/mini/train/image/00122.png
#   inflating: /content/mini/train/image/00123.png
#   inflating: /content/mini/train/image/00124.png
#   inflating: /content/mini/train/image/00125.png
#   inflating: /content/mini/train/image/00126.png
#   inflating: /content/mini/train/image/00127.png
#   inflating: /content/mini/train/image/00128.png
#   inflating: /content/mini/train/image/00129.png
#   inflating: /content/mini/train/image/00130.png
#   inflating: /content/mini/train/image/00131.png
#   inflating: /content/mini/train/image/00132.png
#   inflating: /content/mini/train/image/00133.png
#   inflating: /content/mini/train/image/00134.png
#   inflating: /content/mini/train/image/00135.png
#   inflating: /content/mini/train/image/00136.png
#   inflating: /content/mini/train/image/00137.png
#   inflating: /content/mini/train/image/00138.png
#   inflating: /content/mini/train/image/00139.png
#   inflating: /content/mini/train/image/00140.png
#   inflating: /content/mini/train/image/00141.png
#   inflating: /content/mini/train/image/00142.png
#   inflating: /content/mini/train/image/00143.png
#   inflating: /content/mini/train/image/00144.png
#   inflating: /content/mini/train/image/00145.png
#   inflating: /content/mini/train/image/00146.png
#   inflating: /content/mini/train/image/00147.png
#   inflating: /content/mini/train/image/00148.png
#   inflating: /content/mini/train/image/00149.png
#   inflating: /content/mini/train/image/00150.png
#   inflating: /content/mini/train/image/00151.png
#   inflating: /content/mini/train/image/00152.png
#   inflating: /content/mini/train/image/00153.png
#   inflating: /content/mini/train/image/00154.png
#   inflating: /content/mini/train/image/00155.png
#   inflating: /content/mini/train/image/00156.png
#   inflating: /content/mini/train/image/00157.png
#   inflating: /content/mini/train/image/00158.png
#   inflating: /content/mini/train/image/00159.png
#   inflating: /content/mini/train/image/00160.png
#   inflating: /content/mini/train/image/00161.png
#   inflating: /content/mini/train/image/00162.png
#   inflating: /content/mini/train/image/00163.png
#   inflating: /content/mini/train/image/00164.png
#   inflating: /content/mini/train/image/00165.png
#   inflating: /content/mini/train/image/00166.png
#   inflating: /content/mini/train/image/00167.png
#   inflating: /content/mini/train/image/00168.png
#   inflating: /content/mini/train/image/00169.png
#   inflating: /content/mini/train/image/00170.png
#   inflating: /content/mini/train/image/00171.png
#   inflating: /content/mini/train/image/00172.png
#   inflating: /content/mini/train/image/00173.png
#   inflating: /content/mini/train/image/00174.png
#   inflating: /content/mini/train/image/00175.png
#   inflating: /content/mini/train/image/00176.png
#   inflating: /content/mini/train/image/00177.png
#   inflating: /content/mini/train/image/00178.png
#   inflating: /content/mini/train/image/00179.png
#   inflating: /content/mini/train/image/00180.png
#   inflating: /content/mini/train/image/00181.png
#   inflating: /content/mini/train/image/00182.png
#   inflating: /content/mini/train/image/00183.png
#   inflating: /content/mini/train/image/00184.png
#   inflating: /content/mini/train/image/00185.png
#   inflating: /content/mini/train/image/00186.png
#   inflating: /content/mini/train/image/00187.png
#   inflating: /content/mini/train/image/00188.png
#   inflating: /content/mini/train/image/00189.png
#   inflating: /content/mini/train/image/00190.png
#   inflating: /content/mini/train/image/00191.png
#   inflating: /content/mini/train/image/00192.png
#   inflating: /content/mini/train/image/00193.png
#   inflating: /content/mini/train/image/00194.png
#   inflating: /content/mini/train/image/00195.png
#   inflating: /content/mini/train/image/00196.png
#   inflating: /content/mini/train/image/00197.png
#   inflating: /content/mini/train/image/00198.png
#   inflating: /content/mini/train/image/00199.png
#   inflating: /content/mini/train/image/00200.png
#   inflating: /content/mini/train/image/00201.png
#   inflating: /content/mini/train/image/00202.png
#   inflating: /content/mini/train/image/00203.png
#   inflating: /content/mini/train/image/00204.png
#   inflating: /content/mini/train/image/00205.png
#   inflating: /content/mini/train/image/00206.png
#   inflating: /content/mini/train/image/00207.png
#   inflating: /content/mini/train/image/00208.png
#   inflating: /content/mini/train/image/00209.png
#   inflating: /content/mini/train/image/00210.png
#   inflating: /content/mini/train/image/00211.png
#   inflating: /content/mini/train/image/00212.png
#   inflating: /content/mini/train/image/00213.png
#   inflating: /content/mini/train/image/00214.png
#   inflating: /content/mini/train/image/00215.png
#   inflating: /content/mini/train/image/00216.png
#   inflating: /content/mini/train/image/00217.png
#   inflating: /content/mini/train/image/00218.png
#   inflating: /content/mini/train/image/00219.png
#   inflating: /content/mini/train/image/00220.png
#   inflating: /content/mini/train/image/00221.png
#   inflating: /content/mini/train/image/00222.png
#   inflating: /content/mini/train/image/00223.png
#   inflating: /content/mini/train/image/00224.png
#   inflating: /content/mini/train/image/00225.png
#   inflating: /content/mini/train/image/00226.png
#   inflating: /content/mini/train/image/00227.png
#   inflating: /content/mini/train/image/00228.png
#   inflating: /content/mini/train/image/00229.png
#   inflating: /content/mini/train/image/00230.png
#   inflating: /content/mini/train/image/00231.png
#   inflating: /content/mini/train/image/00232.png
#   inflating: /content/mini/train/image/00233.png
#   inflating: /content/mini/train/image/00234.png
#   inflating: /content/mini/train/image/00235.png
#   inflating: /content/mini/train/image/00236.png
#   inflating: /content/mini/train/image/00237.png
#   inflating: /content/mini/train/image/00238.png
#   inflating: /content/mini/train/image/00239.png
#   inflating: /content/mini/train/image/00240.png
#   inflating: /content/mini/train/image/00241.png
#   inflating: /content/mini/train/image/00242.png
#   inflating: /content/mini/train/image/00243.png
#   inflating: /content/mini/train/image/00244.png
#   inflating: /content/mini/train/image/00245.png
#   inflating: /content/mini/train/image/00246.png
#   inflating: /content/mini/train/image/00247.png
#   inflating: /content/mini/train/image/00248.png
#   inflating: /content/mini/train/image/00249.png
#   inflating: /content/mini/train/image/00250.png
#   inflating: /content/mini/train/image/00251.png
#   inflating: /content/mini/train/image/00252.png
#   inflating: /content/mini/train/image/00253.png
#   inflating: /content/mini/train/image/00254.png
#   inflating: /content/mini/train/image/00255.png
#   inflating: /content/mini/train/image/00256.png
#   inflating: /content/mini/train/image/00257.png
#   inflating: /content/mini/train/image/00258.png
#   inflating: /content/mini/train/image/00259.png
#   inflating: /content/mini/train/image/00260.png
#   inflating: /content/mini/train/image/00261.png
#   inflating: /content/mini/train/image/00262.png
#   inflating: /content/mini/train/image/00263.png
#   inflating: /content/mini/train/image/00264.png
#   inflating: /content/mini/train/image/00265.png
#   inflating: /content/mini/train/image/00266.png
#   inflating: /content/mini/train/image/00267.png
#   inflating: /content/mini/train/image/00268.png
#   inflating: /content/mini/train/image/00269.png
#   inflating: /content/mini/train/image/00270.png
#   inflating: /content/mini/train/image/00271.png
#   inflating: /content/mini/train/image/00272.png
#   inflating: /content/mini/train/image/00273.png
#   inflating: /content/mini/train/image/00274.png
#   inflating: /content/mini/train/image/00275.png
#   inflating: /content/mini/train/image/00276.png
#   inflating: /content/mini/train/image/00277.png
#   inflating: /content/mini/train/image/00278.png
#   inflating: /content/mini/train/image/00279.png
#   inflating: /content/mini/train/image/00280.png
#   inflating: /content/mini/train/image/00281.png
#   inflating: /content/mini/train/image/00282.png
#   inflating: /content/mini/train/image/00283.png
#   inflating: /content/mini/train/image/00284.png
#   inflating: /content/mini/train/image/00285.png
#   inflating: /content/mini/train/image/00286.png
#   inflating: /content/mini/train/image/00287.png
#   inflating: /content/mini/train/image/00288.png
#   inflating: /content/mini/train/image/00289.png
#   inflating: /content/mini/train/image/00290.png
#   inflating: /content/mini/train/image/00291.png
#   inflating: /content/mini/train/image/00292.png
#   inflating: /content/mini/train/image/00293.png
#   inflating: /content/mini/train/image/00294.png
#   inflating: /content/mini/train/image/00295.png
#   inflating: /content/mini/train/image/00296.png
#   inflating: /content/mini/train/image/00297.png
#   inflating: /content/mini/train/image/00298.png
#   inflating: /content/mini/train/image/00299.png
#   inflating: /content/mini/train/image/00300.png
#   inflating: /content/mini/train/image/00301.png
#   inflating: /content/mini/train/image/00302.png
#   inflating: /content/mini/train/image/00303.png
#   inflating: /content/mini/train/image/00304.png
#   inflating: /content/mini/train/image/00305.png
#   inflating: /content/mini/train/image/00306.png
#   inflating: /content/mini/train/image/00307.png
#   inflating: /content/mini/train/image/00308.png
#   inflating: /content/mini/train/image/00309.png
#   inflating: /content/mini/train/image/00310.png
#   inflating: /content/mini/train/image/00311.png
#   inflating: /content/mini/train/image/00312.png
#   inflating: /content/mini/train/image/00313.png
#   inflating: /content/mini/train/image/00314.png
#   inflating: /content/mini/train/image/00315.png
#   inflating: /content/mini/train/image/00316.png
#   inflating: /content/mini/train/image/00317.png
#   inflating: /content/mini/train/image/00318.png
#   inflating: /content/mini/train/image/00319.png
#   inflating: /content/mini/train/image/00320.png
#   inflating: /content/mini/train/image/00321.png
#   inflating: /content/mini/train/image/00322.png
#   inflating: /content/mini/train/image/00323.png
#   inflating: /content/mini/train/image/00324.png
#   inflating: /content/mini/train/image/00325.png
#   inflating: /content/mini/train/image/00326.png
#   inflating: /content/mini/train/image/00327.png
#   inflating: /content/mini/train/image/00328.png
#   inflating: /content/mini/train/image/00329.png
#   inflating: /content/mini/train/image/00330.png
#   inflating: /content/mini/train/image/00331.png
#   inflating: /content/mini/train/image/00332.png
#   inflating: /content/mini/train/image/00333.png
#   inflating: /content/mini/train/image/00334.png
#   inflating: /content/mini/train/image/00335.png
#   inflating: /content/mini/train/image/00336.png
#   inflating: /content/mini/train/image/00337.png
#   inflating: /content/mini/train/image/00338.png
#   inflating: /content/mini/train/image/00339.png
#   inflating: /content/mini/train/image/00340.png
#   inflating: /content/mini/train/image/00341.png
#   inflating: /content/mini/train/image/00342.png
#   inflating: /content/mini/train/image/00343.png
#   inflating: /content/mini/train/image/00344.png
#   inflating: /content/mini/train/image/00345.png
#   inflating: /content/mini/train/image/00346.png
#   inflating: /content/mini/train/image/00347.png
#   inflating: /content/mini/train/image/00348.png
#   inflating: /content/mini/train/image/00349.png
#   inflating: /content/mini/train/image/00350.png
#   inflating: /content/mini/train/image/00351.png
#   inflating: /content/mini/train/image/00352.png
#   inflating: /content/mini/train/image/00353.png
#   inflating: /content/mini/train/image/00354.png
#   inflating: /content/mini/train/image/00355.png
#   inflating: /content/mini/train/image/00356.png
#   inflating: /content/mini/train/image/00357.png
#   inflating: /content/mini/train/image/00358.png
#   inflating: /content/mini/train/image/00359.png
#   inflating: /content/mini/train/image/00360.png
#   inflating: /content/mini/train/image/00361.png
#   inflating: /content/mini/train/image/00362.png
#   inflating: /content/mini/train/image/00363.png
#   inflating: /content/mini/train/image/00364.png
#   inflating: /content/mini/train/image/00365.png
#   inflating: /content/mini/train/image/00366.png
#   inflating: /content/mini/train/image/00367.png
#   inflating: /content/mini/train/image/00368.png
#   inflating: /content/mini/train/image/00369.png
#   inflating: /content/mini/train/image/00370.png
#   inflating: /content/mini/train/image/00371.png
#   inflating: /content/mini/train/image/00372.png
#   inflating: /content/mini/train/image/00373.png
#   inflating: /content/mini/train/image/00374.png
#   inflating: /content/mini/train/image/00375.png
#   inflating: /content/mini/train/image/00376.png
#   inflating: /content/mini/train/image/00377.png
#   inflating: /content/mini/train/image/00378.png
#   inflating: /content/mini/train/image/00379.png
#   inflating: /content/mini/train/image/00380.png
#   inflating: /content/mini/train/image/00381.png
#   inflating: /content/mini/train/image/00382.png
#   inflating: /content/mini/train/image/00383.png
#   inflating: /content/mini/train/image/00384.png
#   inflating: /content/mini/train/image/00385.png
#   inflating: /content/mini/train/image/00386.png
#   inflating: /content/mini/train/image/00387.png
#   inflating: /content/mini/train/image/00388.png
#   inflating: /content/mini/train/image/00389.png
#   inflating: /content/mini/train/image/00390.png
#   inflating: /content/mini/train/image/00391.png
#   inflating: /content/mini/train/image/00392.png
#   inflating: /content/mini/train/image/00393.png
#   inflating: /content/mini/train/image/00394.png
#   inflating: /content/mini/train/image/00395.png
#   inflating: /content/mini/train/image/00396.png
#   inflating: /content/mini/train/image/00397.png
#   inflating: /content/mini/train/image/00398.png
#   inflating: /content/mini/train/image/00399.png
#   inflating: /content/mini/train/image/00400.png
#   inflating: /content/mini/train/image/00401.png
#   inflating: /content/mini/train/image/00402.png
#   inflating: /content/mini/train/image/00403.png
#   inflating: /content/mini/train/image/00404.png
#   inflating: /content/mini/train/image/00405.png
#   inflating: /content/mini/train/image/00406.png
#   inflating: /content/mini/train/image/00407.png
#   inflating: /content/mini/train/image/00408.png
#   inflating: /content/mini/train/image/00409.png
#   inflating: /content/mini/train/image/00410.png
#   inflating: /content/mini/train/image/00411.png
#   inflating: /content/mini/train/image/00412.png
#   inflating: /content/mini/train/image/00413.png
#   inflating: /content/mini/train/image/00414.png
#   inflating: /content/mini/train/image/00415.png
#   inflating: /content/mini/train/image/00416.png
#   inflating: /content/mini/train/image/00417.png
#   inflating: /content/mini/train/image/00418.png
#   inflating: /content/mini/train/image/00419.png
#   inflating: /content/mini/train/image/00420.png
#   inflating: /content/mini/train/image/00421.png
#   inflating: /content/mini/train/image/00422.png
#   inflating: /content/mini/train/image/00423.png
#   inflating: /content/mini/train/image/00424.png
#   inflating: /content/mini/train/image/00425.png
#   inflating: /content/mini/train/image/00426.png
#   inflating: /content/mini/train/image/00427.png
#   inflating: /content/mini/train/image/00428.png
#   inflating: /content/mini/train/image/00429.png
#   inflating: /content/mini/train/image/00430.png
#   inflating: /content/mini/train/image/00431.png
#   inflating: /content/mini/train/image/00432.png
#   inflating: /content/mini/train/image/00433.png
#   inflating: /content/mini/train/image/00434.png
#   inflating: /content/mini/train/image/00435.png
#   inflating: /content/mini/train/image/00436.png
#   inflating: /content/mini/train/image/00437.png
#   inflating: /content/mini/train/image/00438.png
#   inflating: /content/mini/train/image/00439.png
#   inflating: /content/mini/train/image/00440.png
#   inflating: /content/mini/train/image/00441.png
#   inflating: /content/mini/train/image/00442.png
#   inflating: /content/mini/train/image/00443.png
#   inflating: /content/mini/train/image/00444.png
#   inflating: /content/mini/train/image/00445.png
#   inflating: /content/mini/train/image/00446.png
#   inflating: /content/mini/train/image/00447.png
#   inflating: /content/mini/train/image/00448.png
#   inflating: /content/mini/train/image/00449.png
#   inflating: /content/mini/train/image/00450.png
#   inflating: /content/mini/train/image/00451.png
#   inflating: /content/mini/train/image/00452.png
#   inflating: /content/mini/train/image/00453.png
#   inflating: /content/mini/train/image/00454.png
#   inflating: /content/mini/train/image/00455.png
#   inflating: /content/mini/train/image/00456.png
#   inflating: /content/mini/train/image/00457.png
#   inflating: /content/mini/train/image/00458.png
#   inflating: /content/mini/train/image/00459.png
#   inflating: /content/mini/train/image/00460.png
#   inflating: /content/mini/train/image/00461.png
#   inflating: /content/mini/train/image/00462.png
#   inflating: /content/mini/train/image/00463.png
#   inflating: /content/mini/train/image/00464.png
#   inflating: /content/mini/train/image/00465.png
#   inflating: /content/mini/train/image/00466.png
#   inflating: /content/mini/train/image/00467.png
#   inflating: /content/mini/train/image/00468.png
#   inflating: /content/mini/train/image/00469.png
#   inflating: /content/mini/train/image/00470.png
#   inflating: /content/mini/train/image/00471.png
#   inflating: /content/mini/train/image/00472.png
#   inflating: /content/mini/train/image/00473.png
#   inflating: /content/mini/train/image/00474.png
#   inflating: /content/mini/train/image/00475.png
#   inflating: /content/mini/train/image/00476.png
#   inflating: /content/mini/train/image/00477.png
#   inflating: /content/mini/train/image/00478.png
#   inflating: /content/mini/train/image/00479.png
#   inflating: /content/mini/train/image/00480.png
#   inflating: /content/mini/train/image/00481.png
#   inflating: /content/mini/train/image/00482.png
#   inflating: /content/mini/train/image/00483.png
#   inflating: /content/mini/train/image/00484.png
#   inflating: /content/mini/train/image/00485.png
#   inflating: /content/mini/train/image/00486.png
#   inflating: /content/mini/train/image/00487.png
#   inflating: /content/mini/train/image/00488.png
#   inflating: /content/mini/train/image/00489.png
#   inflating: /content/mini/train/image/00490.png
#   inflating: /content/mini/train/image/00491.png
#   inflating: /content/mini/train/image/00492.png
#   inflating: /content/mini/train/image/00493.png
#   inflating: /content/mini/train/image/00494.png
#   inflating: /content/mini/train/image/00495.png
#   inflating: /content/mini/train/image/00496.png
#   inflating: /content/mini/train/image/00497.png
#   inflating: /content/mini/train/image/00498.png
#   inflating: /content/mini/train/image/00499.png
#   inflating: /content/mini/train/image/00500.png
#   inflating: /content/mini/train/mask/00000.png
#   inflating: /content/mini/train/mask/00001.png
#   inflating: /content/mini/train/mask/00002.png
#   inflating: /content/mini/train/mask/00003.png
#   inflating: /content/mini/train/mask/00004.png
#   inflating: /content/mini/train/mask/00005.png
#   inflating: /content/mini/train/mask/00006.png
#   inflating: /content/mini/train/mask/00007.png
#   inflating: /content/mini/train/mask/00008.png
#   inflating: /content/mini/train/mask/00009.png
#   inflating: /content/mini/train/mask/00010.png
#   inflating: /content/mini/train/mask/00011.png
#   inflating: /content/mini/train/mask/00012.png
#   inflating: /content/mini/train/mask/00013.png
#   inflating: /content/mini/train/mask/00014.png
#   inflating: /content/mini/train/mask/00015.png
#   inflating: /content/mini/train/mask/00016.png
#   inflating: /content/mini/train/mask/00017.png
#   inflating: /content/mini/train/mask/00018.png
#   inflating: /content/mini/train/mask/00019.png
#   inflating: /content/mini/train/mask/00020.png
#   inflating: /content/mini/train/mask/00021.png
#   inflating: /content/mini/train/mask/00022.png
#   inflating: /content/mini/train/mask/00023.png
#   inflating: /content/mini/train/mask/00024.png
#   inflating: /content/mini/train/mask/00025.png
#   inflating: /content/mini/train/mask/00026.png
#   inflating: /content/mini/train/mask/00027.png
#   inflating: /content/mini/train/mask/00028.png
#   inflating: /content/mini/train/mask/00029.png
#   inflating: /content/mini/train/mask/00030.png
#   inflating: /content/mini/train/mask/00031.png
#   inflating: /content/mini/train/mask/00032.png
#   inflating: /content/mini/train/mask/00033.png
#   inflating: /content/mini/train/mask/00034.png
#   inflating: /content/mini/train/mask/00035.png
#   inflating: /content/mini/train/mask/00036.png
#   inflating: /content/mini/train/mask/00037.png
#   inflating: /content/mini/train/mask/00038.png
#   inflating: /content/mini/train/mask/00039.png
#   inflating: /content/mini/train/mask/00040.png
#   inflating: /content/mini/train/mask/00041.png
#   inflating: /content/mini/train/mask/00042.png
#   inflating: /content/mini/train/mask/00043.png
#   inflating: /content/mini/train/mask/00044.png
#   inflating: /content/mini/train/mask/00045.png
#   inflating: /content/mini/train/mask/00046.png
#   inflating: /content/mini/train/mask/00047.png
#   inflating: /content/mini/train/mask/00048.png
#   inflating: /content/mini/train/mask/00049.png
#   inflating: /content/mini/train/mask/00050.png
#   inflating: /content/mini/train/mask/00051.png
#   inflating: /content/mini/train/mask/00052.png
#   inflating: /content/mini/train/mask/00053.png
#   inflating: /content/mini/train/mask/00054.png
#   inflating: /content/mini/train/mask/00055.png
#   inflating: /content/mini/train/mask/00056.png
#   inflating: /content/mini/train/mask/00057.png
#   inflating: /content/mini/train/mask/00058.png
#   inflating: /content/mini/train/mask/00059.png
#   inflating: /content/mini/train/mask/00060.png
#   inflating: /content/mini/train/mask/00061.png
#   inflating: /content/mini/train/mask/00062.png
#   inflating: /content/mini/train/mask/00063.png
#   inflating: /content/mini/train/mask/00064.png
#   inflating: /content/mini/train/mask/00065.png
#   inflating: /content/mini/train/mask/00066.png
#   inflating: /content/mini/train/mask/00067.png
#   inflating: /content/mini/train/mask/00068.png
#   inflating: /content/mini/train/mask/00069.png
#   inflating: /content/mini/train/mask/00070.png
#   inflating: /content/mini/train/mask/00071.png
#   inflating: /content/mini/train/mask/00072.png
#   inflating: /content/mini/train/mask/00073.png
#   inflating: /content/mini/train/mask/00074.png
#   inflating: /content/mini/train/mask/00075.png
#   inflating: /content/mini/train/mask/00076.png
#   inflating: /content/mini/train/mask/00077.png
#   inflating: /content/mini/train/mask/00078.png
#   inflating: /content/mini/train/mask/00079.png
#   inflating: /content/mini/train/mask/00080.png
#   inflating: /content/mini/train/mask/00081.png
#   inflating: /content/mini/train/mask/00082.png
#   inflating: /content/mini/train/mask/00083.png
#   inflating: /content/mini/train/mask/00084.png
#   inflating: /content/mini/train/mask/00085.png
#   inflating: /content/mini/train/mask/00086.png
#   inflating: /content/mini/train/mask/00087.png
#   inflating: /content/mini/train/mask/00088.png
#   inflating: /content/mini/train/mask/00089.png
#   inflating: /content/mini/train/mask/00090.png
#   inflating: /content/mini/train/mask/00091.png
#   inflating: /content/mini/train/mask/00092.png
#   inflating: /content/mini/train/mask/00093.png
#   inflating: /content/mini/train/mask/00094.png
#   inflating: /content/mini/train/mask/00095.png
#   inflating: /content/mini/train/mask/00096.png
#   inflating: /content/mini/train/mask/00097.png
#   inflating: /content/mini/train/mask/00098.png
#   inflating: /content/mini/train/mask/00099.png
#   inflating: /content/mini/train/mask/00100.png
#   inflating: /content/mini/train/mask/00101.png
#   inflating: /content/mini/train/mask/00102.png
#   inflating: /content/mini/train/mask/00103.png
#   inflating: /content/mini/train/mask/00104.png
#   inflating: /content/mini/train/mask/00105.png
#   inflating: /content/mini/train/mask/00106.png
#   inflating: /content/mini/train/mask/00107.png
#   inflating: /content/mini/train/mask/00108.png
#   inflating: /content/mini/train/mask/00109.png
#   inflating: /content/mini/train/mask/00110.png
#   inflating: /content/mini/train/mask/00111.png
#   inflating: /content/mini/train/mask/00112.png
#   inflating: /content/mini/train/mask/00113.png
#   inflating: /content/mini/train/mask/00114.png
#   inflating: /content/mini/train/mask/00115.png
#   inflating: /content/mini/train/mask/00116.png
#   inflating: /content/mini/train/mask/00117.png
#   inflating: /content/mini/train/mask/00118.png
#   inflating: /content/mini/train/mask/00119.png
#   inflating: /content/mini/train/mask/00120.png
#   inflating: /content/mini/train/mask/00121.png
#   inflating: /content/mini/train/mask/00122.png
#   inflating: /content/mini/train/mask/00123.png
#   inflating: /content/mini/train/mask/00124.png
#   inflating: /content/mini/train/mask/00125.png
#   inflating: /content/mini/train/mask/00126.png
#   inflating: /content/mini/train/mask/00127.png
#   inflating: /content/mini/train/mask/00128.png
#   inflating: /content/mini/train/mask/00129.png
#   inflating: /content/mini/train/mask/00130.png
#   inflating: /content/mini/train/mask/00131.png
#   inflating: /content/mini/train/mask/00132.png
#   inflating: /content/mini/train/mask/00133.png
#   inflating: /content/mini/train/mask/00134.png
#   inflating: /content/mini/train/mask/00135.png
#   inflating: /content/mini/train/mask/00136.png
#   inflating: /content/mini/train/mask/00137.png
#   inflating: /content/mini/train/mask/00138.png
#   inflating: /content/mini/train/mask/00139.png
#   inflating: /content/mini/train/mask/00140.png
#   inflating: /content/mini/train/mask/00141.png
#   inflating: /content/mini/train/mask/00142.png
#   inflating: /content/mini/train/mask/00143.png
#   inflating: /content/mini/train/mask/00144.png
#   inflating: /content/mini/train/mask/00145.png
#   inflating: /content/mini/train/mask/00146.png
#   inflating: /content/mini/train/mask/00147.png
#   inflating: /content/mini/train/mask/00148.png
#   inflating: /content/mini/train/mask/00149.png
#   inflating: /content/mini/train/mask/00150.png
#   inflating: /content/mini/train/mask/00151.png
#   inflating: /content/mini/train/mask/00152.png
#   inflating: /content/mini/train/mask/00153.png
#   inflating: /content/mini/train/mask/00154.png
#   inflating: /content/mini/train/mask/00155.png
#   inflating: /content/mini/train/mask/00156.png
#   inflating: /content/mini/train/mask/00157.png
#   inflating: /content/mini/train/mask/00158.png
#   inflating: /content/mini/train/mask/00159.png
#   inflating: /content/mini/train/mask/00160.png
#   inflating: /content/mini/train/mask/00161.png
#   inflating: /content/mini/train/mask/00162.png
#   inflating: /content/mini/train/mask/00163.png
#   inflating: /content/mini/train/mask/00164.png
#   inflating: /content/mini/train/mask/00165.png
#   inflating: /content/mini/train/mask/00166.png
#   inflating: /content/mini/train/mask/00167.png
#   inflating: /content/mini/train/mask/00168.png
#   inflating: /content/mini/train/mask/00169.png
#   inflating: /content/mini/train/mask/00170.png
#   inflating: /content/mini/train/mask/00171.png
#   inflating: /content/mini/train/mask/00172.png
#   inflating: /content/mini/train/mask/00173.png
#   inflating: /content/mini/train/mask/00174.png
#   inflating: /content/mini/train/mask/00175.png
#   inflating: /content/mini/train/mask/00176.png
#   inflating: /content/mini/train/mask/00177.png
#   inflating: /content/mini/train/mask/00178.png
#   inflating: /content/mini/train/mask/00179.png
#   inflating: /content/mini/train/mask/00180.png
#   inflating: /content/mini/train/mask/00181.png
#   inflating: /content/mini/train/mask/00182.png
#   inflating: /content/mini/train/mask/00183.png
#   inflating: /content/mini/train/mask/00184.png
#   inflating: /content/mini/train/mask/00185.png
#   inflating: /content/mini/train/mask/00186.png
#   inflating: /content/mini/train/mask/00187.png
#   inflating: /content/mini/train/mask/00188.png
#   inflating: /content/mini/train/mask/00189.png
#   inflating: /content/mini/train/mask/00190.png
#   inflating: /content/mini/train/mask/00191.png
#   inflating: /content/mini/train/mask/00192.png
#   inflating: /content/mini/train/mask/00193.png
#   inflating: /content/mini/train/mask/00194.png
#   inflating: /content/mini/train/mask/00195.png
#   inflating: /content/mini/train/mask/00196.png
#   inflating: /content/mini/train/mask/00197.png
#   inflating: /content/mini/train/mask/00198.png
#   inflating: /content/mini/train/mask/00199.png
#   inflating: /content/mini/train/mask/00200.png
#   inflating: /content/mini/train/mask/00201.png
#   inflating: /content/mini/train/mask/00202.png
#   inflating: /content/mini/train/mask/00203.png
#   inflating: /content/mini/train/mask/00204.png
#   inflating: /content/mini/train/mask/00205.png
#   inflating: /content/mini/train/mask/00206.png
#   inflating: /content/mini/train/mask/00207.png
#   inflating: /content/mini/train/mask/00208.png
#   inflating: /content/mini/train/mask/00209.png
#   inflating: /content/mini/train/mask/00210.png
#   inflating: /content/mini/train/mask/00211.png
#   inflating: /content/mini/train/mask/00212.png
#   inflating: /content/mini/train/mask/00213.png
#   inflating: /content/mini/train/mask/00214.png
#   inflating: /content/mini/train/mask/00215.png
#   inflating: /content/mini/train/mask/00216.png
#   inflating: /content/mini/train/mask/00217.png
#   inflating: /content/mini/train/mask/00218.png
#   inflating: /content/mini/train/mask/00219.png
#   inflating: /content/mini/train/mask/00220.png
#   inflating: /content/mini/train/mask/00221.png
#   inflating: /content/mini/train/mask/00222.png
#   inflating: /content/mini/train/mask/00223.png
#   inflating: /content/mini/train/mask/00224.png
#   inflating: /content/mini/train/mask/00225.png
#   inflating: /content/mini/train/mask/00226.png
#   inflating: /content/mini/train/mask/00227.png
#   inflating: /content/mini/train/mask/00228.png
#   inflating: /content/mini/train/mask/00229.png
#   inflating: /content/mini/train/mask/00230.png
#   inflating: /content/mini/train/mask/00231.png
#   inflating: /content/mini/train/mask/00232.png
#   inflating: /content/mini/train/mask/00233.png
#   inflating: /content/mini/train/mask/00234.png
#   inflating: /content/mini/train/mask/00235.png
#   inflating: /content/mini/train/mask/00236.png
#   inflating: /content/mini/train/mask/00237.png
#   inflating: /content/mini/train/mask/00238.png
#   inflating: /content/mini/train/mask/00239.png
#   inflating: /content/mini/train/mask/00240.png
#   inflating: /content/mini/train/mask/00241.png
#   inflating: /content/mini/train/mask/00242.png
#   inflating: /content/mini/train/mask/00243.png
#   inflating: /content/mini/train/mask/00244.png
#   inflating: /content/mini/train/mask/00245.png
#   inflating: /content/mini/train/mask/00246.png
#   inflating: /content/mini/train/mask/00247.png
#   inflating: /content/mini/train/mask/00248.png
#   inflating: /content/mini/train/mask/00249.png
#   inflating: /content/mini/train/mask/00250.png
#   inflating: /content/mini/train/mask/00251.png
#   inflating: /content/mini/train/mask/00252.png
#   inflating: /content/mini/train/mask/00253.png
#   inflating: /content/mini/train/mask/00254.png
#   inflating: /content/mini/train/mask/00255.png
#   inflating: /content/mini/train/mask/00256.png
#   inflating: /content/mini/train/mask/00257.png
#   inflating: /content/mini/train/mask/00258.png
#   inflating: /content/mini/train/mask/00259.png
#   inflating: /content/mini/train/mask/00260.png
#   inflating: /content/mini/train/mask/00261.png
#   inflating: /content/mini/train/mask/00262.png
#   inflating: /content/mini/train/mask/00263.png
#   inflating: /content/mini/train/mask/00264.png
#   inflating: /content/mini/train/mask/00265.png
#   inflating: /content/mini/train/mask/00266.png
#   inflating: /content/mini/train/mask/00267.png
#   inflating: /content/mini/train/mask/00268.png
#   inflating: /content/mini/train/mask/00269.png
#   inflating: /content/mini/train/mask/00270.png
#   inflating: /content/mini/train/mask/00271.png
#   inflating: /content/mini/train/mask/00272.png
#   inflating: /content/mini/train/mask/00273.png
#   inflating: /content/mini/train/mask/00274.png
#   inflating: /content/mini/train/mask/00275.png
#   inflating: /content/mini/train/mask/00276.png
#   inflating: /content/mini/train/mask/00277.png
#   inflating: /content/mini/train/mask/00278.png
#   inflating: /content/mini/train/mask/00279.png
#   inflating: /content/mini/train/mask/00280.png
#   inflating: /content/mini/train/mask/00281.png
#   inflating: /content/mini/train/mask/00282.png
#   inflating: /content/mini/train/mask/00283.png
#   inflating: /content/mini/train/mask/00284.png
#   inflating: /content/mini/train/mask/00285.png
#   inflating: /content/mini/train/mask/00286.png
#   inflating: /content/mini/train/mask/00287.png
#   inflating: /content/mini/train/mask/00288.png
#   inflating: /content/mini/train/mask/00289.png
#   inflating: /content/mini/train/mask/00290.png
#   inflating: /content/mini/train/mask/00291.png
#   inflating: /content/mini/train/mask/00292.png
#   inflating: /content/mini/train/mask/00293.png
#   inflating: /content/mini/train/mask/00294.png
#   inflating: /content/mini/train/mask/00295.png
#   inflating: /content/mini/train/mask/00296.png
#   inflating: /content/mini/train/mask/00297.png
#   inflating: /content/mini/train/mask/00298.png
#   inflating: /content/mini/train/mask/00299.png
#   inflating: /content/mini/train/mask/00300.png
#   inflating: /content/mini/train/mask/00301.png
#   inflating: /content/mini/train/mask/00302.png
#   inflating: /content/mini/train/mask/00303.png
#   inflating: /content/mini/train/mask/00304.png
#   inflating: /content/mini/train/mask/00305.png
#   inflating: /content/mini/train/mask/00306.png
#   inflating: /content/mini/train/mask/00307.png
#   inflating: /content/mini/train/mask/00308.png
#   inflating: /content/mini/train/mask/00309.png
#   inflating: /content/mini/train/mask/00310.png
#   inflating: /content/mini/train/mask/00311.png
#   inflating: /content/mini/train/mask/00312.png
#   inflating: /content/mini/train/mask/00313.png
#   inflating: /content/mini/train/mask/00314.png
#   inflating: /content/mini/train/mask/00315.png
#   inflating: /content/mini/train/mask/00316.png
#   inflating: /content/mini/train/mask/00317.png
#   inflating: /content/mini/train/mask/00318.png
#   inflating: /content/mini/train/mask/00319.png
#   inflating: /content/mini/train/mask/00320.png
#   inflating: /content/mini/train/mask/00321.png
#   inflating: /content/mini/train/mask/00322.png
#   inflating: /content/mini/train/mask/00323.png
#   inflating: /content/mini/train/mask/00324.png
#   inflating: /content/mini/train/mask/00325.png
#   inflating: /content/mini/train/mask/00326.png
#   inflating: /content/mini/train/mask/00327.png
#   inflating: /content/mini/train/mask/00328.png
#   inflating: /content/mini/train/mask/00329.png
#   inflating: /content/mini/train/mask/00330.png
#   inflating: /content/mini/train/mask/00331.png
#   inflating: /content/mini/train/mask/00332.png
#   inflating: /content/mini/train/mask/00333.png
#   inflating: /content/mini/train/mask/00334.png
#   inflating: /content/mini/train/mask/00335.png
#   inflating: /content/mini/train/mask/00336.png
#   inflating: /content/mini/train/mask/00337.png
#   inflating: /content/mini/train/mask/00338.png
#   inflating: /content/mini/train/mask/00339.png
#   inflating: /content/mini/train/mask/00340.png
#   inflating: /content/mini/train/mask/00341.png
#   inflating: /content/mini/train/mask/00342.png
#   inflating: /content/mini/train/mask/00343.png
#   inflating: /content/mini/train/mask/00344.png
#   inflating: /content/mini/train/mask/00345.png
#   inflating: /content/mini/train/mask/00346.png
#   inflating: /content/mini/train/mask/00347.png
#   inflating: /content/mini/train/mask/00348.png
#   inflating: /content/mini/train/mask/00349.png
#   inflating: /content/mini/train/mask/00350.png
#   inflating: /content/mini/train/mask/00351.png
#   inflating: /content/mini/train/mask/00352.png
#   inflating: /content/mini/train/mask/00353.png
#   inflating: /content/mini/train/mask/00354.png
#   inflating: /content/mini/train/mask/00355.png
#   inflating: /content/mini/train/mask/00356.png
#   inflating: /content/mini/train/mask/00357.png
#   inflating: /content/mini/train/mask/00358.png
#   inflating: /content/mini/train/mask/00359.png
#   inflating: /content/mini/train/mask/00360.png
#   inflating: /content/mini/train/mask/00361.png
#   inflating: /content/mini/train/mask/00362.png
#   inflating: /content/mini/train/mask/00363.png
#   inflating: /content/mini/train/mask/00364.png
#   inflating: /content/mini/train/mask/00365.png
#   inflating: /content/mini/train/mask/00366.png
#   inflating: /content/mini/train/mask/00367.png
#   inflating: /content/mini/train/mask/00368.png
#   inflating: /content/mini/train/mask/00369.png
#   inflating: /content/mini/train/mask/00370.png
#   inflating: /content/mini/train/mask/00371.png
#   inflating: /content/mini/train/mask/00372.png
#   inflating: /content/mini/train/mask/00373.png
#   inflating: /content/mini/train/mask/00374.png
#   inflating: /content/mini/train/mask/00375.png
#   inflating: /content/mini/train/mask/00376.png
#   inflating: /content/mini/train/mask/00377.png
#   inflating: /content/mini/train/mask/00378.png
#   inflating: /content/mini/train/mask/00379.png
#   inflating: /content/mini/train/mask/00380.png
#   inflating: /content/mini/train/mask/00381.png
#   inflating: /content/mini/train/mask/00382.png
#   inflating: /content/mini/train/mask/00383.png
#   inflating: /content/mini/train/mask/00384.png
#   inflating: /content/mini/train/mask/00385.png
#   inflating: /content/mini/train/mask/00386.png
#   inflating: /content/mini/train/mask/00387.png
#   inflating: /content/mini/train/mask/00388.png
#   inflating: /content/mini/train/mask/00389.png
#   inflating: /content/mini/train/mask/00390.png
#   inflating: /content/mini/train/mask/00391.png
#   inflating: /content/mini/train/mask/00392.png
#   inflating: /content/mini/train/mask/00393.png
#   inflating: /content/mini/train/mask/00394.png
#   inflating: /content/mini/train/mask/00395.png
#   inflating: /content/mini/train/mask/00396.png
#   inflating: /content/mini/train/mask/00397.png
#   inflating: /content/mini/train/mask/00398.png
#   inflating: /content/mini/train/mask/00399.png
#   inflating: /content/mini/train/mask/00400.png
#   inflating: /content/mini/train/mask/00401.png
#   inflating: /content/mini/train/mask/00402.png
#   inflating: /content/mini/train/mask/00403.png
#   inflating: /content/mini/train/mask/00404.png
#   inflating: /content/mini/train/mask/00405.png
#   inflating: /content/mini/train/mask/00406.png
#   inflating: /content/mini/train/mask/00407.png
#   inflating: /content/mini/train/mask/00408.png
#   inflating: /content/mini/train/mask/00409.png
#   inflating: /content/mini/train/mask/00410.png
#   inflating: /content/mini/train/mask/00411.png
#   inflating: /content/mini/train/mask/00412.png
#   inflating: /content/mini/train/mask/00413.png
#   inflating: /content/mini/train/mask/00414.png
#   inflating: /content/mini/train/mask/00415.png
#   inflating: /content/mini/train/mask/00416.png
#   inflating: /content/mini/train/mask/00417.png
#   inflating: /content/mini/train/mask/00418.png
#   inflating: /content/mini/train/mask/00419.png
#   inflating: /content/mini/train/mask/00420.png
#   inflating: /content/mini/train/mask/00421.png
#   inflating: /content/mini/train/mask/00422.png
#   inflating: /content/mini/train/mask/00423.png
#   inflating: /content/mini/train/mask/00424.png
#   inflating: /content/mini/train/mask/00425.png
#   inflating: /content/mini/train/mask/00426.png
#   inflating: /content/mini/train/mask/00427.png
#   inflating: /content/mini/train/mask/00428.png
#   inflating: /content/mini/train/mask/00429.png
#   inflating: /content/mini/train/mask/00430.png
#   inflating: /content/mini/train/mask/00431.png
#   inflating: /content/mini/train/mask/00432.png
#   inflating: /content/mini/train/mask/00433.png
#   inflating: /content/mini/train/mask/00434.png
#   inflating: /content/mini/train/mask/00435.png
#   inflating: /content/mini/train/mask/00436.png
#   inflating: /content/mini/train/mask/00437.png
#   inflating: /content/mini/train/mask/00438.png
#   inflating: /content/mini/train/mask/00439.png
#   inflating: /content/mini/train/mask/00440.png
#   inflating: /content/mini/train/mask/00441.png
#   inflating: /content/mini/train/mask/00442.png
#   inflating: /content/mini/train/mask/00443.png
#   inflating: /content/mini/train/mask/00444.png
#   inflating: /content/mini/train/mask/00445.png
# ...
#   inflating: /content/mini/val/image/00270.png
#   inflating: /content/mini/val/image/00271.png
#   inflating: /content/mini/val/image/00272.png
#   inflating: /content/mini/val/image/00273.png
#   inflating: /content/mini/val/image/00274.png
#   inflating: /content/mini/val/image/00275.png
#   inflating: /content/mini/val/image/00276.png
#   inflating: /content/mini/val/image/00277.png
#   inflating: /content/mini/val/image/00278.png
#   inflating: /content/mini/val/image/00279.png
#   inflating: /content/mini/val/image/00280.png
#   inflating: /content/mini/val/image/00281.png
#   inflating: /content/mini/val/image/00282.png
#   inflating: /content/mini/val/image/00283.png
#   inflating: /content/mini/val/image/00284.png
#   inflating: /content/mini/val/image/00285.png
#   inflating: /content/mini/val/image/00286.png
#   inflating: /content/mini/val/image/00287.png
#   inflating: /content/mini/val/image/00288.png
#   inflating: /content/mini/val/image/00289.png
#   inflating: /content/mini/val/image/00290.png
#   inflating: /content/mini/val/image/00291.png
#   inflating: /content/mini/val/image/00292.png
#   inflating: /content/mini/val/image/00293.png
#   inflating: /content/mini/val/image/00294.png
#   inflating: /content/mini/val/image/00295.png
#   inflating: /content/mini/val/image/00296.png
#   inflating: /content/mini/val/image/00297.png
#   inflating: /content/mini/val/image/00298.png
#   inflating: /content/mini/val/image/00299.png
#   inflating: /content/mini/val/image/00300.png
#   inflating: /content/mini/val/mask/00000.png
#   inflating: /content/mini/val/mask/00001.png
#   inflating: /content/mini/val/mask/00002.png
#   inflating: /content/mini/val/mask/00003.png
#   inflating: /content/mini/val/mask/00004.png
#   inflating: /content/mini/val/mask/00005.png
#   inflating: /content/mini/val/mask/00006.png
#   inflating: /content/mini/val/mask/00007.png
#   inflating: /content/mini/val/mask/00008.png
#   inflating: /content/mini/val/mask/00009.png
#   inflating: /content/mini/val/mask/00010.png
#   inflating: /content/mini/val/mask/00011.png
#   inflating: /content/mini/val/mask/00012.png
#   inflating: /content/mini/val/mask/00013.png
#   inflating: /content/mini/val/mask/00014.png
#   inflating: /content/mini/val/mask/00015.png
#   inflating: /content/mini/val/mask/00016.png
#   inflating: /content/mini/val/mask/00017.png
#   inflating: /content/mini/val/mask/00018.png
#   inflating: /content/mini/val/mask/00019.png
#   inflating: /content/mini/val/mask/00020.png
#   inflating: /content/mini/val/mask/00021.png
#   inflating: /content/mini/val/mask/00022.png
#   inflating: /content/mini/val/mask/00023.png
#   inflating: /content/mini/val/mask/00024.png
#   inflating: /content/mini/val/mask/00025.png
#   inflating: /content/mini/val/mask/00026.png
#   inflating: /content/mini/val/mask/00027.png
#   inflating: /content/mini/val/mask/00028.png
#   inflating: /content/mini/val/mask/00029.png
#   inflating: /content/mini/val/mask/00030.png
#   inflating: /content/mini/val/mask/00031.png
#   inflating: /content/mini/val/mask/00032.png
#   inflating: /content/mini/val/mask/00033.png
#   inflating: /content/mini/val/mask/00034.png
#   inflating: /content/mini/val/mask/00035.png
#   inflating: /content/mini/val/mask/00036.png
#   inflating: /content/mini/val/mask/00037.png
#   inflating: /content/mini/val/mask/00038.png
#   inflating: /content/mini/val/mask/00039.png
#   inflating: /content/mini/val/mask/00040.png
#   inflating: /content/mini/val/mask/00041.png
#   inflating: /content/mini/val/mask/00042.png
#   inflating: /content/mini/val/mask/00043.png
#   inflating: /content/mini/val/mask/00044.png
#   inflating: /content/mini/val/mask/00045.png
#   inflating: /content/mini/val/mask/00046.png
#   inflating: /content/mini/val/mask/00047.png
#   inflating: /content/mini/val/mask/00048.png
#   inflating: /content/mini/val/mask/00049.png
#   inflating: /content/mini/val/mask/00050.png
#   inflating: /content/mini/val/mask/00051.png
#   inflating: /content/mini/val/mask/00052.png
#   inflating: /content/mini/val/mask/00053.png
#   inflating: /content/mini/val/mask/00054.png
#   inflating: /content/mini/val/mask/00055.png
#   inflating: /content/mini/val/mask/00056.png
#   inflating: /content/mini/val/mask/00057.png
#   inflating: /content/mini/val/mask/00058.png
#   inflating: /content/mini/val/mask/00059.png
#   inflating: /content/mini/val/mask/00060.png
#   inflating: /content/mini/val/mask/00061.png
#   inflating: /content/mini/val/mask/00062.png
#   inflating: /content/mini/val/mask/00063.png
#   inflating: /content/mini/val/mask/00064.png
#   inflating: /content/mini/val/mask/00065.png
#   inflating: /content/mini/val/mask/00066.png
#   inflating: /content/mini/val/mask/00067.png
#   inflating: /content/mini/val/mask/00068.png
#   inflating: /content/mini/val/mask/00069.png
#   inflating: /content/mini/val/mask/00070.png
#   inflating: /content/mini/val/mask/00071.png
#   inflating: /content/mini/val/mask/00072.png
#   inflating: /content/mini/val/mask/00073.png
#   inflating: /content/mini/val/mask/00074.png
#   inflating: /content/mini/val/mask/00075.png
#   inflating: /content/mini/val/mask/00076.png
#   inflating: /content/mini/val/mask/00077.png
#   inflating: /content/mini/val/mask/00078.png
#   inflating: /content/mini/val/mask/00079.png
#   inflating: /content/mini/val/mask/00080.png
#   inflating: /content/mini/val/mask/00081.png
#   inflating: /content/mini/val/mask/00082.png
#   inflating: /content/mini/val/mask/00083.png
#   inflating: /content/mini/val/mask/00084.png
#   inflating: /content/mini/val/mask/00085.png
#   inflating: /content/mini/val/mask/00086.png
#   inflating: /content/mini/val/mask/00087.png
#   inflating: /content/mini/val/mask/00088.png
#   inflating: /content/mini/val/mask/00089.png
#   inflating: /content/mini/val/mask/00090.png
#   inflating: /content/mini/val/mask/00091.png
#   inflating: /content/mini/val/mask/00092.png
#   inflating: /content/mini/val/mask/00093.png
#   inflating: /content/mini/val/mask/00094.png
#   inflating: /content/mini/val/mask/00095.png
#   inflating: /content/mini/val/mask/00096.png
#   inflating: /content/mini/val/mask/00097.png
#   inflating: /content/mini/val/mask/00098.png
#   inflating: /content/mini/val/mask/00099.png
#   inflating: /content/mini/val/mask/00100.png
#   inflating: /content/mini/val/mask/00101.png
#   inflating: /content/mini/val/mask/00102.png
#   inflating: /content/mini/val/mask/00103.png
#   inflating: /content/mini/val/mask/00104.png
#   inflating: /content/mini/val/mask/00105.png
#   inflating: /content/mini/val/mask/00106.png
#   inflating: /content/mini/val/mask/00107.png
#   inflating: /content/mini/val/mask/00108.png
#   inflating: /content/mini/val/mask/00109.png
#   inflating: /content/mini/val/mask/00110.png
#   inflating: /content/mini/val/mask/00111.png
#   inflating: /content/mini/val/mask/00112.png
#   inflating: /content/mini/val/mask/00113.png
#   inflating: /content/mini/val/mask/00114.png
#   inflating: /content/mini/val/mask/00115.png
#   inflating: /content/mini/val/mask/00116.png
#   inflating: /content/mini/val/mask/00117.png
#   inflating: /content/mini/val/mask/00118.png
#   inflating: /content/mini/val/mask/00119.png
#   inflating: /content/mini/val/mask/00120.png
#   inflating: /content/mini/val/mask/00121.png
#   inflating: /content/mini/val/mask/00122.png
#   inflating: /content/mini/val/mask/00123.png
#   inflating: /content/mini/val/mask/00124.png
#   inflating: /content/mini/val/mask/00125.png
#   inflating: /content/mini/val/mask/00126.png
#   inflating: /content/mini/val/mask/00127.png
#   inflating: /content/mini/val/mask/00128.png
#   inflating: /content/mini/val/mask/00129.png
#   inflating: /content/mini/val/mask/00130.png
#   inflating: /content/mini/val/mask/00131.png
#   inflating: /content/mini/val/mask/00132.png
#   inflating: /content/mini/val/mask/00133.png
#   inflating: /content/mini/val/mask/00134.png
#   inflating: /content/mini/val/mask/00135.png
#   inflating: /content/mini/val/mask/00136.png
#   inflating: /content/mini/val/mask/00137.png
#   inflating: /content/mini/val/mask/00138.png
#   inflating: /content/mini/val/mask/00139.png
#   inflating: /content/mini/val/mask/00140.png
#   inflating: /content/mini/val/mask/00141.png
#   inflating: /content/mini/val/mask/00142.png
#   inflating: /content/mini/val/mask/00143.png
#   inflating: /content/mini/val/mask/00144.png
#   inflating: /content/mini/val/mask/00145.png
#   inflating: /content/mini/val/mask/00146.png
#   inflating: /content/mini/val/mask/00147.png
#   inflating: /content/mini/val/mask/00148.png
#   inflating: /content/mini/val/mask/00149.png
#   inflating: /content/mini/val/mask/00150.png
#   inflating: /content/mini/val/mask/00151.png
#   inflating: /content/mini/val/mask/00152.png
#   inflating: /content/mini/val/mask/00153.png
#   inflating: /content/mini/val/mask/00154.png
#   inflating: /content/mini/val/mask/00155.png
#   inflating: /content/mini/val/mask/00156.png
#   inflating: /content/mini/val/mask/00157.png
#   inflating: /content/mini/val/mask/00158.png
#   inflating: /content/mini/val/mask/00159.png
#   inflating: /content/mini/val/mask/00160.png
#   inflating: /content/mini/val/mask/00161.png
#   inflating: /content/mini/val/mask/00162.png
#   inflating: /content/mini/val/mask/00163.png
#   inflating: /content/mini/val/mask/00164.png
#   inflating: /content/mini/val/mask/00165.png
#   inflating: /content/mini/val/mask/00166.png
#   inflating: /content/mini/val/mask/00167.png
#   inflating: /content/mini/val/mask/00168.png
#   inflating: /content/mini/val/mask/00169.png
#   inflating: /content/mini/val/mask/00170.png
#   inflating: /content/mini/val/mask/00171.png
#   inflating: /content/mini/val/mask/00172.png
#   inflating: /content/mini/val/mask/00173.png
#   inflating: /content/mini/val/mask/00174.png
#   inflating: /content/mini/val/mask/00175.png
#   inflating: /content/mini/val/mask/00176.png
#   inflating: /content/mini/val/mask/00177.png
#   inflating: /content/mini/val/mask/00178.png
#   inflating: /content/mini/val/mask/00179.png
#   inflating: /content/mini/val/mask/00180.png
#   inflating: /content/mini/val/mask/00181.png
#   inflating: /content/mini/val/mask/00182.png
#   inflating: /content/mini/val/mask/00183.png
#   inflating: /content/mini/val/mask/00184.png
#   inflating: /content/mini/val/mask/00185.png
#   inflating: /content/mini/val/mask/00186.png
#   inflating: /content/mini/val/mask/00187.png
#   inflating: /content/mini/val/mask/00188.png
#   inflating: /content/mini/val/mask/00189.png
#   inflating: /content/mini/val/mask/00190.png
#   inflating: /content/mini/val/mask/00191.png
#   inflating: /content/mini/val/mask/00192.png
#   inflating: /content/mini/val/mask/00193.png
#   inflating: /content/mini/val/mask/00194.png
#   inflating: /content/mini/val/mask/00195.png
#   inflating: /content/mini/val/mask/00196.png
#   inflating: /content/mini/val/mask/00197.png
#   inflating: /content/mini/val/mask/00198.png
#   inflating: /content/mini/val/mask/00199.png
#   inflating: /content/mini/val/mask/00200.png
#   inflating: /content/mini/val/mask/00201.png
#   inflating: /content/mini/val/mask/00202.png
#   inflating: /content/mini/val/mask/00203.png
#   inflating: /content/mini/val/mask/00204.png
#   inflating: /content/mini/val/mask/00205.png
#   inflating: /content/mini/val/mask/00206.png
#   inflating: /content/mini/val/mask/00207.png
#   inflating: /content/mini/val/mask/00208.png
#   inflating: /content/mini/val/mask/00209.png
#   inflating: /content/mini/val/mask/00210.png
#   inflating: /content/mini/val/mask/00211.png
#   inflating: /content/mini/val/mask/00212.png
#   inflating: /content/mini/val/mask/00213.png
#   inflating: /content/mini/val/mask/00214.png
#   inflating: /content/mini/val/mask/00215.png
#   inflating: /content/mini/val/mask/00216.png
#   inflating: /content/mini/val/mask/00217.png
#   inflating: /content/mini/val/mask/00218.png
#   inflating: /content/mini/val/mask/00219.png
#   inflating: /content/mini/val/mask/00220.png
#   inflating: /content/mini/val/mask/00221.png
#   inflating: /content/mini/val/mask/00222.png
#   inflating: /content/mini/val/mask/00223.png
#   inflating: /content/mini/val/mask/00224.png
#   inflating: /content/mini/val/mask/00225.png
#   inflating: /content/mini/val/mask/00226.png
#   inflating: /content/mini/val/mask/00227.png
#   inflating: /content/mini/val/mask/00228.png
#   inflating: /content/mini/val/mask/00229.png
#   inflating: /content/mini/val/mask/00230.png
#   inflating: /content/mini/val/mask/00231.png
#   inflating: /content/mini/val/mask/00232.png
#   inflating: /content/mini/val/mask/00233.png
#   inflating: /content/mini/val/mask/00234.png
#   inflating: /content/mini/val/mask/00235.png
#   inflating: /content/mini/val/mask/00236.png
#   inflating: /content/mini/val/mask/00237.png
#   inflating: /content/mini/val/mask/00238.png
#   inflating: /content/mini/val/mask/00239.png
#   inflating: /content/mini/val/mask/00240.png
#   inflating: /content/mini/val/mask/00241.png
#   inflating: /content/mini/val/mask/00242.png
#   inflating: /content/mini/val/mask/00243.png
#   inflating: /content/mini/val/mask/00244.png
#   inflating: /content/mini/val/mask/00245.png
#   inflating: /content/mini/val/mask/00246.png
#   inflating: /content/mini/val/mask/00247.png
#   inflating: /content/mini/val/mask/00248.png
#   inflating: /content/mini/val/mask/00249.png
#   inflating: /content/mini/val/mask/00250.png
#   inflating: /content/mini/val/mask/00251.png
#   inflating: /content/mini/val/mask/00252.png
#   inflating: /content/mini/val/mask/00253.png
#   inflating: /content/mini/val/mask/00254.png
#   inflating: /content/mini/val/mask/00255.png
#   inflating: /content/mini/val/mask/00256.png
#   inflating: /content/mini/val/mask/00257.png
#   inflating: /content/mini/val/mask/00258.png
#   inflating: /content/mini/val/mask/00259.png
#   inflating: /content/mini/val/mask/00260.png
#   inflating: /content/mini/val/mask/00261.png
#   inflating: /content/mini/val/mask/00262.png
#   inflating: /content/mini/val/mask/00263.png
#   inflating: /content/mini/val/mask/00264.png
#   inflating: /content/mini/val/mask/00265.png
#   inflating: /content/mini/val/mask/00266.png
#   inflating: /content/mini/val/mask/00267.png
#   inflating: /content/mini/val/mask/00268.png
#   inflating: /content/mini/val/mask/00269.png
#   inflating: /content/mini/val/mask/00270.png
#   inflating: /content/mini/val/mask/00271.png
#   inflating: /content/mini/val/mask/00272.png
#   inflating: /content/mini/val/mask/00273.png
#   inflating: /content/mini/val/mask/00274.png
#   inflating: /content/mini/val/mask/00275.png
#   inflating: /content/mini/val/mask/00276.png
#   inflating: /content/mini/val/mask/00277.png
#   inflating: /content/mini/val/mask/00278.png
#   inflating: /content/mini/val/mask/00279.png
#   inflating: /content/mini/val/mask/00280.png
#   inflating: /content/mini/val/mask/00281.png
#   inflating: /content/mini/val/mask/00282.png
#   inflating: /content/mini/val/mask/00283.png
#   inflating: /content/mini/val/mask/00284.png
#   inflating: /content/mini/val/mask/00285.png
#   inflating: /content/mini/val/mask/00286.png
#   inflating: /content/mini/val/mask/00287.png
#   inflating: /content/mini/val/mask/00288.png
#   inflating: /content/mini/val/mask/00289.png
#   inflating: /content/mini/val/mask/00290.png
#   inflating: /content/mini/val/mask/00291.png
#   inflating: /content/mini/val/mask/00292.png
#   inflating: /content/mini/val/mask/00293.png
#   inflating: /content/mini/val/mask/00294.png
#   inflating: /content/mini/val/mask/00295.png
#   inflating: /content/mini/val/mask/00296.png
#   inflating: /content/mini/val/mask/00297.png
#   inflating: /content/mini/val/mask/00298.png
#   inflating: /content/mini/val/mask/00299.png
#   inflating: /content/mini/val/mask/00300.png

# %% [markdown]
# # Dataset de segmentació
#
# A l’hora de treballar amb tasques de segmentació d’imatges, és essencial tenir un conjunt de dades que inclogui tant les imatges d’entrada com les màscares que representen les etiquetes de segmentació. Un dataset per segmentació ha de contenir:
#
# 1. Imatges d’entrada: Aquestes són les imatges que el model utilitzarà per aprendre. Poden estar en formats com JPEG o PNG.
# 2. Màscares de segmentació: Cada màscara és una imatge on cada píxel té un valor que representa la classe a la qual pertany (per exemple, 0 per fons, 1 per objecte). Les màscares han de tenir la mateixa mida que les imatges d’entrada.

# %%
import os
from PIL import Image
import torch
from torch.utils.data import Dataset
import numpy as np
from torchvision import transforms

class Formes(Dataset):
    """
    TXUKI segmentation dataset.

    CORRECCIÓ: Aquesta versió accepta llistes de rutes de fitxers ja pre-seleccionades,
    en lloc d'una única ruta de directori.
    """
    # El constructor ara espera llistes de rutes completes (img_files, label_files)
    def __init__(self, img_files, mask_files, transform=None):
        # NOTA: Canviem 'img_dir' i 'mask_dir' per 'img_files' i 'mask_files'

        # Guardem directament les llistes de rutes completes
        self.img_filenames = img_files
        self.mask_filenames = mask_files
        self.transform = transform

        # Definim les transformacions de màscara només una vegada
        self.mask_transforms = transforms.Compose([
            transforms.ToTensor(),
            transforms.Lambda(lambda x: x.squeeze().long()) # (C, H, W) -> (H, W) amb dtype int64
        ])

        # Si es proporciona un transform, assumim que només afecta a la imatge
        self.image_only_transforms = self.transform or transforms.ToTensor()


    def __len__(self):
        # Retorna la longitud de la llista de fitxers
        return len(self.img_filenames)


    def __getitem__(self, idx):
        # Utilitzem directament les rutes completes guardades
        img_path = self.img_filenames[idx]
        mask_path = self.mask_filenames[idx]

        # 1. Carregar imatge i màscara
        image = Image.open(img_path).convert('RGB')
        mask = Image.open(mask_path).convert('L')

        # 2. Aplicar transformacions
        # Aplicar les transformacions de la imatge (ToTensor i Normalització)
        image = self.image_only_transforms(image)

        # Aplicar les transformacions de la màscara (ToTensor i LongTensor)
        mask = self.mask_transforms(mask)

        return image, mask

# %% [markdown]
# Per instanciar aquest tipus de dataset es similar a com ho hem fet fins ara. **Per tal de simplificar l'entrenament només emprarem 500 mostres per l'entrenament i 200 de test**.

# %%
PATH_DADES = "./mini"  # POSA EL TEU!
# Dades entrenament
path_train = f"{PATH_DADES}/train"

img_files = sorted(glob(path_train + "/image/*.png"))
label_files = sorted(glob(path_train + "/mask/*.png"))
img_files = img_files[:500]
label_files = label_files[:500]

print("total training images", len(img_files))

# Dades validacio

path_val = f"{PATH_DADES}/val"
img_files_val = sorted(glob(path_val + "/image/*.png"))
label_files_val = sorted(glob(path_val + "/mask/*.png"))
img_files_val = img_files_val[:200]
label_files_val = label_files_val[:200]

print("total test images", len(img_files_val))
# Out:
# total training images 500
# total test images 200

# %%
train_batch_size = 4
test_batch_size = 4

# Definim una seqüència (composició) de transformacions
transform = transforms.Compose([
    transforms.ToTensor(),
    ## TODO: Put if necessary
])

train_data = Formes(img_files, label_files, transform)
val_data = Formes(img_files_val, label_files_val, transform)

train_loader = torch.utils.data.DataLoader(train_data, train_batch_size)
val_loader = torch.utils.data.DataLoader(val_data, test_batch_size)

# %% [markdown]
# ## Entrenament
# L’entrenament d’una xarxa U-Net consisteix a ensenyar al model a predir les màscares de segmentació corresponents a les imatges d’entrada. Aquest procés implica ajustar els pesos de la xarxa per minimitzar l’error entre les prediccions i les etiquetes reals (màscares). En aquesta secció, configurarem tot el necessari per entrenar el model amb el conjunt de dades generat prèviament.
#
# Hi ha tot un conjunt de peculiaritats que fan que aquest entrenament difereixi respecte els vists fins ara:
# - **Funció de pèrdua**. El Dice Coefficient és una mesura d’avaluació utilitzada en segmentació d’imatges per comparar la superposició entre la màscara predita i la màscara real. El seu valor oscil·la entre 0 (cap coincidència) i 1 (coincidència perfecta), i es calcula com el doble de la intersecció entre les dues màscares dividit per la seva suma total. També es pot emprar ``BCE``.
# - **Sortida de la xarxa**. El tipus de problema determina el nombre de canals de sortida de la U-Net: per segmentació binària, la sortida és un únic canal amb valors que representen la probabilitat de pertànyer a la classe positiva (fons o objecte). En canvi, per segmentació multiclasse, la sortida té un canal per a cada classe i els valors representen la probabilitat de cada píxel de pertànyer a cadascuna de les classes.
# - **Funcions d'activació**. Les funcions d'activació a la sortida d'una U-Net depenen del tipus de segmentació: en segmentació binària, s'utilitza una sigmoid per comprimir els valors entre 0 i 1, representant la probabilitat de pertànyer a la classe positiva. En segmentació, **sense superposició**, multiclasse, s'aplica una softmax per convertir els valors de cada canal en probabilitats normalitzades, assegurant que la suma sigui 1 per píxel.
#
# ### El model

# %%
import torch.nn as nn

class UNetConvBlock(nn.Module):
    def __init__(self, in_size, out_size):
        super(UNetConvBlock, self).__init__()

        # El bloc conté dues operacions seqüencials de Conv -> BatchNorm -> ReLU
        self.block = nn.Sequential(
            # Primera Convolució (3x3 amb padding=1 per mantenir la mida espacial)
            nn.Conv2d(in_size, out_size, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_size),
            nn.ReLU(inplace=True),

            # Segona Convolució
            nn.Conv2d(out_size, out_size, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_size),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        # Simplement passa l'entrada a través de la seqüència de capes
        return self.block(x)

# %%
class UNet(nn.Module):
    def __init__(self, in_channels=3, out_channels=1, init_features=32):
        super(UNet, self).__init__()

        features = init_features

        # 1. ENCODER (Path Contractant)
        self.encoder1 = UNetConvBlock(in_channels, features)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.encoder2 = UNetConvBlock(features, features * 2)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.encoder3 = UNetConvBlock(features * 2, features * 4)
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.encoder4 = UNetConvBlock(features * 4, features * 8)
        self.pool4 = nn.MaxPool2d(kernel_size=2, stride=2)

        # 2. BOTTLENECK
        self.bottleneck = UNetConvBlock(features * 8, features * 16)

        # 3. DECODER (Path Expansiu)
        self.upconv4 = nn.ConvTranspose2d(features * 16, features * 8, kernel_size=2, stride=2)
        self.decoder4 = UNetConvBlock(features * 16, features * 8)

        self.upconv3 = nn.ConvTranspose2d(features * 8, features * 4, kernel_size=2, stride=2)
        self.decoder3 = UNetConvBlock(features * 8, features * 4)

        self.upconv2 = nn.ConvTranspose2d(features * 4, features * 2, kernel_size=2, stride=2)
        self.decoder2 = UNetConvBlock(features * 4, features * 2)

        self.upconv1 = nn.ConvTranspose2d(features * 2, features, kernel_size=2, stride=2)
        self.decoder1 = UNetConvBlock(features * 2, features)

        # 4. CAPA DE SORTIDA (Convolució 1x1 per mapejar al nombre de classes)
        self.conv_out = nn.Conv2d(features, out_channels, kernel_size=1)


    def forward(self, x):
        # Encoder
        e1 = self.encoder1(x)
        p1 = self.pool1(e1)

        e2 = self.encoder2(p1)
        p2 = self.pool2(e2)

        e3 = self.encoder3(p2)
        p3 = self.pool3(e3)

        e4 = self.encoder4(p3)
        p4 = self.pool4(e4)

        # Bottleneck
        bottleneck = self.bottleneck(p4)

        # Decoder amb Skip Connections (Concat)
        d4 = self.upconv4(bottleneck)
        d4 = torch.cat((d4, e4), dim=1)
        d4 = self.decoder4(d4)

        d3 = self.upconv3(d4)
        d3 = torch.cat((d3, e3), dim=1)
        d3 = self.decoder3(d3)

        d2 = self.upconv2(d3)
        d2 = torch.cat((d2, e2), dim=1)
        d2 = self.decoder2(d2)

        d1 = self.upconv1(d2)
        d1 = torch.cat((d1, e1), dim=1)
        d1 = self.decoder1(d1)

        # Sortida (Logits)
        output = self.conv_out(d1)

        return output

# %% [markdown]
# ## La funció de pèrdua
#
# Per fer tasques de segmentació, una de les funcions de pèrdua que podem emprar és el _Diceloss_ (intersecció vs unió):  El coeficient de _Dice_ s'utilitza habitualment en tasques de segmentació d'imatges com a mesura de la superposició entre les màscares de segmentació entre la predicció i el _ground truth_. El  _Diceloss_, és el complementari del coeficient de _Dice_, es pot utilitzar com a funció de pèrdua per entrenar models per a tasques de segmentació.
#
# Dice Coefficient $= 2 \times \frac{|X \cap Y|}{|X| + |Y|}$
#
#
#
# On:
#
# - $X$ és la màscara de segmentació prevista.
# - $Y$ és la màscara de segmentació de la veritat del sòl.
# - $∣⋅∣$ denota la cardinalitat o el nombre d'elements d'un conjunt.

# %%
class DiceLoss(nn.Module):

    def __init__(self):
        super(DiceLoss, self).__init__()
        self.smooth = 0.0

    def forward(self, y_pred, y_true):
        assert y_pred.size() == y_true.size()
        y_pred = y_pred[:, 0].contiguous().view(-1)
        y_true = y_true[:, 0].contiguous().view(-1)
        intersection = (y_pred * y_true).sum()
        dsc = (2. * intersection + self.smooth) / (
                y_pred.sum() + y_true.sum() + self.smooth
        )
        return 1. - dsc

# %% [markdown]
# ### Bucle d'entrenament
#
# El bucle d'entrenament és un poc diferent al vist fins ara. En particular, en aquests moments els gràfics es van actualitzant a mesura que aprèn i així podem tenir un idea de cm va l'entrenament.

# %%
import torch.nn as nn
import torch

class BCELoss(nn.Module):
    """
    Classe que encapsula nn.BCEWithLogitsLoss.
    Aquesta loss és ideal per a segmentació binària amb sortides de logits,
    ja que gestiona la Sigmoid internament per a una millor estabilitat numèrica.
    """
    def __init__(self):
        super().__init__()
        # Utilitzem BCEWithLogitsLoss de PyTorch
        self.loss = nn.BCEWithLogitsLoss()

    def forward(self, y_pred, y_true):
        # BCEWithLogitsLoss espera que el target (y_true) sigui del tipus float.
        # Ho convertim a float just abans de calcular la pèrdua.
        return self.loss(y_pred, y_true.float())

# %%
# --- CONFIGURACIÓ ---
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Utilitzant dispositiu: {device}")

# out_channels=1 per a segmentació binària (Fons vs. Formes)
model = UNet(in_channels=3, out_channels=1, init_features=32).to(device)

# Paràmetres
learning_rate = 1e-4
num_epochs = 15 # Valor suggerit per veure progressos
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Funció de pèrdua combinada (Exemple: Ponderació de les dues pèrdues)
criterion_dice = DiceLoss()
criterion_bce = BCELoss()

# Llista per guardar l'historial
train_losses = []

# --- BUCLE D'ENTRENAMENT ---
print("Començant l'entrenament...")
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0.0

    # Utilitzem tqdm per a una barra de progrés
    train_loop = tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs} (Train)")

    for i, (images, masks) in enumerate(train_loop):
        images, masks = images.to(device), masks.to(device)

        # La UNet espera C=1 a la sortida, així que afegim la dimensió de canal a la màscara (B, H, W) -> (B, 1, H, W)
        masks_input = masks.unsqueeze(1)

        optimizer.zero_grad()

        # Forward pass
        outputs = model(images)

        # Càlcul de la pèrdua: Pèrdua combinada
        loss_dice = criterion_dice(outputs, masks_input)
        loss_bce = criterion_bce(outputs, masks_input)

        # Ponderació 50/50 per beneficiar-se d'ambdues
        loss = 0.5 * loss_bce + 0.5 * loss_dice

        # Backward pass i optimització
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()

        # Actualitzar la barra de progrés
        train_loop.set_postfix(loss=loss.item())

    avg_epoch_loss = epoch_loss / len(train_loader)
    train_losses.append(avg_epoch_loss)

    # Actualització visual del gràfic
    display.clear_output(wait=True)
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Training Loss')
    plt.title(f"Evolució de la Pèrdua Combinada | Epoch: {epoch+1}")
    plt.xlabel("Epoch")
    plt.ylabel("Loss (Dice + BCE)")
    plt.legend()
    plt.grid(True)
    display.display(plt.gcf())
    plt.close()

print("Entrenament finalitzat.")
# Out:
# Entrenament finalitzat.

# %% [markdown]
# # Tasques a fer
#
# 1. Implementa la U-Net per detectar les formes geomètriques.
# 2. Empra com a funció de pèrdua tant la ``Dice`` com la ``BCE``, quina diferència hi ha?
# 3. Fer un nou entrenament per segmentar de forma separada els diferents tipus de figura. Has d'adaptar el model. Quins canvis faries?
